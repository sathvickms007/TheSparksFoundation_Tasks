# %% [markdown]
# # GRIP @ The Sparks Foundation
# # Batch: Oct 2023
# # Data Science & Business Analytics
# # Task 4 - EDA on Global Terrorism ML
# # By M S Sathvick

# %% [markdown]
# ![Screenshot%20%287%29.png](attachment:Screenshot%20%287%29.png)

# %%
#Importing necessary Libraries

# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sb
# %matplotlib inline

# %%
df=pd.read_csv("globalterrorismdb_0718dist.csv",encoding="latin1")
a=df
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_25900\3897666146.py:1: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("globalterrorismdb_0718dist.csv",encoding="latin1")

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
for i in a.columns:
    print(i,end=", ")
# Out:
# eventid, iyear, imonth, iday, approxdate, extended, resolution, country, country_txt, region, region_txt, provstate, city, latitude, longitude, specificity, vicinity, location, summary, crit1, crit2, crit3, doubtterr, alternative, alternative_txt, multiple, success, suicide, attacktype1, attacktype1_txt, attacktype2, attacktype2_txt, attacktype3, attacktype3_txt, targtype1, targtype1_txt, targsubtype1, targsubtype1_txt, corp1, target1, natlty1, natlty1_txt, targtype2, targtype2_txt, targsubtype2, targsubtype2_txt, corp2, target2, natlty2, natlty2_txt, targtype3, targtype3_txt, targsubtype3, targsubtype3_txt, corp3, target3, natlty3, natlty3_txt, gname, gsubname, gname2, gsubname2, gname3, gsubname3, motive, guncertain1, guncertain2, guncertain3, individual, nperps, nperpcap, claimed, claimmode, claimmode_txt, claim2, claimmode2, claimmode2_txt, claim3, claimmode3, claimmode3_txt, compclaim, weaptype1, weaptype1_txt, weapsubtype1, weapsubtype1_txt, weaptype2, weaptype2_txt, weapsubtyp
# ...

# %%
for i in df.columns:
    print(i,end=", ")
# Out:
# eventid, iyear, imonth, iday, approxdate, extended, resolution, country, country_txt, region, region_txt, provstate, city, latitude, longitude, specificity, vicinity, location, summary, crit1, crit2, crit3, doubtterr, alternative, alternative_txt, multiple, success, suicide, attacktype1, attacktype1_txt, attacktype2, attacktype2_txt, attacktype3, attacktype3_txt, targtype1, targtype1_txt, targsubtype1, targsubtype1_txt, corp1, target1, natlty1, natlty1_txt, targtype2, targtype2_txt, targsubtype2, targsubtype2_txt, corp2, target2, natlty2, natlty2_txt, targtype3, targtype3_txt, targsubtype3, targsubtype3_txt, corp3, target3, natlty3, natlty3_txt, gname, gsubname, gname2, gsubname2, gname3, gsubname3, motive, guncertain1, guncertain2, guncertain3, individual, nperps, nperpcap, claimed, claimmode, claimmode_txt, claim2, claimmode2, claimmode2_txt, claim3, claimmode3, claimmode3_txt, compclaim, weaptype1, weaptype1_txt, weapsubtype1, weapsubtype1_txt, weaptype2, weaptype2_txt, weapsubtyp
# ...

# %%
for i in df.columns:
    print(i, df[i].nunique())
# Out:
# eventid 181691
# iyear 47
# imonth 13
# iday 32
# approxdate 2244
# extended 2
# resolution 1859
# country 205
# country_txt 205
# region 12
# region_txt 12
# provstate 2855
# city 36673
# latitude 48322
# longitude 48039
# specificity 5
# vicinity 3
# location 44109
# summary 112492
# crit1 2
# crit2 2
# crit3 2
# doubtterr 3
# alternative 5
# alternative_txt 5
# multiple 2
# success 2
# suicide 2
# attacktype1 9
# attacktype1_txt 9
# attacktype2 9
# attacktype2_txt 9
# attacktype3 8
# attacktype3_txt 8
# targtype1 22
# targtype1_txt 22
# targsubtype1 112
# targsubtype1_txt 112
# corp1 33237
# target1 86005
# natlty1 215
# natlty1_txt 215
# targtype2 22
# targtype2_txt 22
# targsubtype2 107
# targsubtype2_txt 107
# corp2 2691
# target2 5043
# natlty2 158
# natlty2_txt 158
# targtype3 20
# targtype3_txt 20
# targsubtype3 92
# targsubtype3_txt 92
# corp3 422
# target3 720
# natlty3 110
# natlty3_txt 110
# gname 3537
# gsubname 1183
# gname2 433
# gsubname2 60
# gname3 116
# ...

# %%
#Data Cleaning

# %%
#Feature Selection

# %%
df=df[["iyear","imonth","iday","country_txt","region_txt","provstate","city",
       "latitude","longitude","location","summary","attacktype1_txt","targtype1_txt",
       "gname","motive","weaptype1_txt","nkill","nwound","addnotes"]]
df.head()
# Out:
#    iyear  imonth  iday         country_txt                   region_txt  \
# 0   1970       7     2  Dominican Republic  Central America & Caribbean
# 1   1970       0     0              Mexico                North America
# 2   1970       1     0         Philippines               Southeast Asia
# 3   1970       1     0              Greece               Western Europe
# 4   1970       1     0               Japan                    East Asia
#
#   provstate           city   latitude   longitude location summary  \
# 0       NaN  Santo Domingo  18.456792  -69.951164      NaN     NaN
# 1   Federal    Mexico city  19.371887  -99.086624      NaN     NaN
# 2    Tarlac        Unknown  15.478598  120.599741      NaN     NaN
# 3    Attica         Athens  37.997490   23.762728      NaN     NaN
# 4   Fukouka        Fukouka  33.580412  130.396361      NaN     NaN
#
#                   attacktype1_txt                targtype1_txt  \
# ...

# %%
df.rename(columns={"iyear":"Year","imonth":"Month","iday":"Day","country_txt":"Country",
                   "region_txt":"Region","provstate":"Province/State","city":"City",
                   "latitude":"Latitude","longitude":"Longitude","location":"Location",
                   "summary":"Summary","attacktype1_txt":"Attack Type","targtype1_txt":"Target Type",
                   "gname":"Group Name","motive":"Motive","weaptype1_txt":"Weapon Type",
                   "nkill":"Killed","nwound":"Wounded","addnotes":"Add Notes"},inplace=True)
df.head()
temp=df
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_25900\636661954.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={"iyear":"Year","imonth":"Month","iday":"Day","country_txt":"Country",

# %%
df.describe()
# Out:
#                 Year          Month            Day       Latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean     2002.638997       6.467277      15.505644      23.498343
# std        13.259430       3.388303       8.814045      18.569242
# min      1970.000000       0.000000       0.000000     -53.154613
# 25%      1991.000000       4.000000       8.000000      11.510046
# 50%      2009.000000       6.000000      15.000000      31.467463
# 75%      2014.000000       9.000000      23.000000      34.685087
# max      2017.000000      12.000000      31.000000      74.633553
#
#           Longitude         Killed        Wounded
# count  1.771340e+05  171378.000000  165380.000000
# mean  -4.586957e+02       2.403272       3.167668
# std    2.047790e+05      11.545741      35.949392
# min   -8.618590e+07       0.000000       0.000000
# 25%    4.545640e+00       0.000000       0.000000
# 50%    4.324651e+01       0.000000       0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 19 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Year            181691 non-null  int64
#  1   Month           181691 non-null  int64
#  2   Day             181691 non-null  int64
#  3   Country         181691 non-null  object
#  4   Region          181691 non-null  object
#  5   Province/State  181270 non-null  object
#  6   City            181256 non-null  object
#  7   Latitude        177135 non-null  float64
#  8   Longitude       177134 non-null  float64
#  9   Location        55495 non-null   object
#  10  Summary         115562 non-null  object
#  11  Attack Type     181691 non-null  object
#  12  Target Type     181691 non-null  object
#  13  Group Name      181691 non-null  object
#  14  Motive          50561 non-null   object
#  15  Weapon Type     181691 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# Year                   0
# Month                  0
# Day                    0
# Country                0
# Region                 0
# Province/State       421
# City                 435
# Latitude            4556
# Longitude           4557
# Location          126196
# Summary            66129
# Attack Type            0
# Target Type            0
# Group Name             0
# Motive            131130
# Weapon Type            0
# Killed             10313
# Wounded            16311
# Add Notes         153402
# dtype: int64

# %%
df.shape
# Out:
# (181691, 19)

# %%
df.head()
# Out:
#    Year  Month  Day             Country                       Region  \
# 0  1970      7    2  Dominican Republic  Central America & Caribbean
# 1  1970      0    0              Mexico                North America
# 2  1970      1    0         Philippines               Southeast Asia
# 3  1970      1    0              Greece               Western Europe
# 4  1970      1    0               Japan                    East Asia
#
#   Province/State           City   Latitude   Longitude Location Summary  \
# 0            NaN  Santo Domingo  18.456792  -69.951164      NaN     NaN
# 1        Federal    Mexico city  19.371887  -99.086624      NaN     NaN
# 2         Tarlac        Unknown  15.478598  120.599741      NaN     NaN
# 3         Attica         Athens  37.997490   23.762728      NaN     NaN
# 4        Fukouka        Fukouka  33.580412  130.396361      NaN     NaN
#
#                       Attack Type                  Target Type  \
# ...

# %%
df.describe()
# Out:
#                 Year          Month            Day       Latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean     2002.638997       6.467277      15.505644      23.498343
# std        13.259430       3.388303       8.814045      18.569242
# min      1970.000000       0.000000       0.000000     -53.154613
# 25%      1991.000000       4.000000       8.000000      11.510046
# 50%      2009.000000       6.000000      15.000000      31.467463
# 75%      2014.000000       9.000000      23.000000      34.685087
# max      2017.000000      12.000000      31.000000      74.633553
#
#           Longitude         Killed        Wounded
# count  1.771340e+05  171378.000000  165380.000000
# mean  -4.586957e+02       2.403272       3.167668
# std    2.047790e+05      11.545741      35.949392
# min   -8.618590e+07       0.000000       0.000000
# 25%    4.545640e+00       0.000000       0.000000
# 50%    4.324651e+01       0.000000       0.000000
# ...

# %%
#EDA

# %%
yearwise_attacks = df.groupby('Year').size().reset_index(name='count')
sb.lineplot(x='Year', y='count', data=yearwise_attacks, color='red')
plt.xlabel('Year')
plt.ylabel('Count of Attacks')
plt.title("Terrorist Attacks")
plt.show()

# %%
yearwise_attacks.describe()
# Out:
#               Year         count
# count    47.000000     47.000000
# mean   1993.510638   3865.765957
# std      14.151160   3836.943826
# min    1970.000000    471.000000
# 25%    1981.500000   1364.000000
# 50%    1994.000000   2870.000000
# 75%    2005.500000   4503.500000
# max    2017.000000  16903.000000

# %%
#Observation:
#Maximum no. of attacks was recorded on the year 2017

# %%
regions_attacked = df.groupby(['Year','Region']).size().reset_index(name='count')
plt.subplots(figsize=(15,6))
sb.lineplot(x='Year',y='count',hue='Region',data=regions_attacked)
plt.title('Region wise attacks')
plt.xlabel('Year')
plt.ylabel('Number of Attacks')
plt.show()

# %%
plt.subplots(figsize=(15,6))
sb.countplot(x='Region',data=df,palette='inferno',order=df['Region'].value_counts().index)
plt.xticks(rotation=80)
plt.title('count of Terrorist activities grouped by regions')
plt.show()

# %%
at=df["Attack Type"].value_counts()

# %%
#Max. no. of Terrorist attacks were performed using Explosives

# %%
plt.subplots(figsize=(15,6))
sb.barplot(x = df['Country'].value_counts()[:15].index, y = df['Country'].value_counts()[:15].values,palette='inferno')
plt.title('Countries Affected')
plt.xlabel('Countries')
plt.ylabel('Count')
plt.xticks(rotation= 90)
plt.show()

# %%
df.Country.value_counts()[:]
# Out:
# Country
# Iraq                   24636
# Pakistan               14368
# Afghanistan            12731
# India                  11960
# Colombia                8306
#                        ...
# International              1
# Wallis and Futuna          1
# South Vietnam              1
# Andorra                    1
# Antigua and Barbuda        1
# Name: count, Length: 205, dtype: int64

# %%
#Iraq faced the most no. of attacks numerically 24636

# %%
#Terrorist attacks in India
Ind = a[(temp['Country'] == 'India')]
attacks_in_India = Ind['eventid'].count()
Ind
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 1186    197202220004   1972       2    22        NaN         0        NaN
# 2764    197501190004   1975       1     2        NaN         0        NaN
# 3857    197605260001   1976       5    26        NaN         0        NaN
# 5327    197709280004   1977       9    28        NaN         0        NaN
# 7337    197901130004   1979       1    13        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181663  201712300021   2017      12    30        NaN         0        NaN
# 181665  201712300023   2017      12    30        NaN         0        NaN
# 181672  201712310005   2017      12    31        NaN         0        NaN
# 181684  201712310019   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
#
#         country country_txt  region  ...  \
# ...

# %%
#No. of attacks in INdia
attacks_in_India

# %%
df.columns

# %%
groups = a[['attacktype1_txt','gname','weaptype1_txt','targtype1']]
group_counts = groups['gname'].value_counts()
sort = group_counts.sort_values(ascending=False)
sort = sort.iloc[1:]
top_5 = sort.head(5)


sb.set(style="whitegrid")

plt.figure(figsize=(12, 6))
sb.barplot(x=top_5.index, y=top_5.values, palette="viridis")
plt.title('Top 5 Terrorist communities')
plt.xlabel('Attack Count')
plt.ylabel('Group')
plt.xticks(rotation = 90)
plt.show()

# %%
a[(a["gname"]=="Taliban")].count()

# %%
#Taliban Terrorist Group has the highest blame of 7478 attacks.

# %% [markdown]
# Final Analysis through conclusion:
# 1.Explosives are the most commonly used attack type, accounting for 49% of all incidents.
# 2.Firearms follow closely behind, representing 28% of attacks.
# 3.Other methods, such as chemicals or vehicles, make up the remaining 23%.
# 4.The Middle East and South Asia are the most affected regions, accounting for 54% of all recorded attacks.
# 5.Other regions, such as Sub-Saharan Africa and Southeast Asia, also experience a significant percentage of attacks.
# 6.The maximum number of casualities witnessed in an attack was 935736.

# %% [markdown]
# Thank You!
